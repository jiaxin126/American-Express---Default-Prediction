# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt, gc, os
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

#pca
from sklearn.decomposition import PCA
from sklearn.decomposition import IncrementalPCA

#lightgbm
from sklearn.model_selection import train_test_split
import lightgbm as lgb
from lightgbm import LGBMClassifier, early_stopping

#xgbm
import xgboost as xgb
from xgboost import XGBClassifier

#catboost
import catboost as cb
from catboost import CatBoostClassifier

#decision tree
from sklearn.tree import DecisionTreeClassifier

#random forest
from sklearn.ensemble import RandomForestClassifier

#logistic regression
from sklearn.linear_model import LogisticRegression

#metrics
from pathlib import Path
input_path = Path('/kaggle/input/amex-default-prediction/')

# %% [markdown]
# # Load Data

# %%
TRAIN_PATH = '/Users/wangjiaxin/Desktop/study program/data analysis/project/amex/train.parquet'
train = pd.read_parquet(TRAIN_PATH)
train.shape
# Out:
# (5531451, 190)

# %%
#change format of ['customer_ID'],['S_2']
train['customer_ID'] = train['customer_ID'].str[-16:].apply(lambda x: int(x, 16))
train.S_2 = pd.to_datetime( train.S_2 )
train.head()
# Out:
#             customer_ID        S_2       P_2  D_39       B_1       B_2  \
# 0  13914591055249847850 2017-03-09  0.938469     0  0.008724  1.006838
# 1  13914591055249847850 2017-04-07  0.936665     0  0.004923  1.000653
# 2  13914591055249847850 2017-05-28  0.954180     3  0.021655  1.009672
# 3  13914591055249847850 2017-06-13  0.960384     0  0.013683  1.002700
# 4  13914591055249847850 2017-07-16  0.947248     0  0.015193  1.000727
#
#         R_1       S_3  D_41       B_3  ...  D_136  D_137  D_138  D_139  D_140  \
# 0  0.009228  0.124035   0.0  0.004709  ...     -1     -1     -1      0      0
# 1  0.006151  0.126750   0.0  0.002714  ...     -1     -1     -1      0      0
# 2  0.006815  0.123977   0.0  0.009423  ...     -1     -1     -1      0      0
# 3  0.001373  0.117169   0.0  0.005531  ...     -1     -1     -1      0      0
# 4  0.007605  0.117325   0.0  0.009312  ...     -1     -1     -1      0      0
#
#    D_141  D_142  D_143     D_144  D_145
# 0    0.0    NaN      0  0.000610      0
# 1    0.0    NaN      0  0.005492      0
# 2    0.0    NaN      0  0.006986      0
# 3    0.0    NaN      0  0.006527      0
# 4    0.0    NaN      0  0.008126      0
#
# [5 rows x 190 columns]

# %%
y = pd.read_csv('/Users/wangjiaxin/Desktop/study program/data analysis/project/amex/train_labels.csv')
#from string to int
y['customer_ID'] = y['customer_ID'].str[-16:].apply(lambda x: int(x, 16))
y=y.set_index('customer_ID')
y.head()
# Out:
#                       target
# customer_ID
# 13914591055249847850       0
# 11750091188498716901       0
# 7128959966677571777        0
# 6537921148391624412        0
# 2065103583825424365        0

# %%
len(y)
# Out:
# 458913

# %%
#target value
c = dict(y['target'].value_counts())
c
# Out:
# {0: 340085, 1: 118828}

# %% [markdown]
# # AMEX Metric

# %%
def amex_metric(y_true: pd.DataFrame, y_pred: pd.DataFrame) -> float:

    def top_four_percent_captured(y_true: pd.DataFrame, y_pred: pd.DataFrame) -> float:
        df = (pd.concat([y_true, y_pred], axis='columns')
              .sort_values('prediction', ascending=False))
        df['weight'] = df['target'].apply(lambda x: 20 if x==0 else 1)
        four_pct_cutoff = int(0.04 * df['weight'].sum())
        df['weight_cumsum'] = df['weight'].cumsum()
        df_cutoff = df.loc[df['weight_cumsum'] <= four_pct_cutoff]
        return (df_cutoff['target'] == 1).sum() / (df['target'] == 1).sum()
        
    def weighted_gini(y_true: pd.DataFrame, y_pred: pd.DataFrame) -> float:
        df = (pd.concat([y_true, y_pred], axis='columns')
              .sort_values('prediction', ascending=False))
        df['weight'] = df['target'].apply(lambda x: 20 if x==0 else 1)
        df['random'] = (df['weight'] / df['weight'].sum()).cumsum()
        total_pos = (df['target'] * df['weight']).sum()
        df['cum_pos_found'] = (df['target'] * df['weight']).cumsum()
        df['lorentz'] = df['cum_pos_found'] / total_pos
        df['gini'] = (df['lorentz'] - df['random']) * df['weight']
        return df['gini'].sum()

    def normalized_weighted_gini(y_true: pd.DataFrame, y_pred: pd.DataFrame) -> float:
        y_true_pred = y_true.rename(columns={'target': 'prediction'})
        return weighted_gini(y_true, y_pred) / weighted_gini(y_true, y_true_pred)

    g = normalized_weighted_gini(y_true, y_pred)
    d = top_four_percent_captured(y_true, y_pred)

    return 0.5 * (g + d)

# %% [markdown]
# # Feature Engineering

# %%
#handle duplicates
# keep only the last record for each customer
train.drop_duplicates('customer_ID',keep='last',inplace=True)
train=train.set_index('customer_ID')

# %% [markdown]
# ### Deal with Missing Values

# %%
#dealing with missing value
def check_value(df):
        zero_val = (df == 0.00).astype(int).sum(axis=0)
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mz_table = pd.concat([zero_val, mis_val, mis_val_percent], axis=1)
        mz_table = mz_table.rename(
        columns = {0 : 'Zero Values', 1 : 'Missing Values', 2 : '% Missing'})
        mz_table['Data Type'] = df.dtypes
        mz_table = mz_table[
            mz_table.iloc[:,1] != 0].sort_values(
        '% Missing', ascending=False).round(1)
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns and " + str(df.shape[0]) + " Rows.\n"      
            "There are " + str(mz_table.shape[0]) +
              " columns that have missing values.")
        return mz_table

# %%
train.shape
# Out:
# (458913, 189)

# %%
Missing_values_table_train = check_value(train)
train_null_tables= Missing_values_table_train.loc[Missing_values_table_train['% Missing'] > 70]
train_null_tables['Unique'] = [train[col].nunique() for col in train_null_tables.index ]
print (train_null_tables)
# Out:
# Your selected dataframe has 189 columns and 458913 Rows.
# There are 58 columns that have missing values.
#        Zero Values  Missing Values  % Missing Data Type  Unique
# D_88             0          458086       99.8   float32     827
# D_110            0          455235       99.2   float32    3665
# B_39             0          454808       99.1   float32    4105
# D_73             0          454674       99.1   float32    4239
# B_42             0          452771       98.7   float32    6141
# D_134            0          442518       96.4   float32   16377
# B_29             0          431589       94.0   float32   27308
# D_76             0          409597       89.3   float32   49301
# D_132            0          407153       88.7   float32   51736
# D_42             0          399003       86.9   float32   59874
# D_142            0          378598       82.5   float32   80151
# D_53             0          325932       71.0   float32  132847

# %%
#drop columns with more than 80% missing values
train = train.drop(columns = ['D_88','D_110','B_39','D_73','B_42','D_134','B_29','D_132','D_76','D_42','D_142'])

# %%
train.dtypes.value_counts()
# Out:
# int8              86
# float32           82
# int16              9
# datetime64[ns]     1
# dtype: int64

# %%
#dealing with categorical data, fill in with mode
#dealing with numeric data, fill in with mean 
cat_col=['B_30', 'B_38', 'D_114', 'D_116', 'D_117', 'D_120', 'D_126', 'D_63', 'D_64', 'D_66', 'D_68']
for col in list(train.columns):
    if col in cat_col:
        train[col] = train[col].fillna(train[col].mode().iloc[0])
    else:
        train[col] = train[col].fillna(train[col].mean())
        
print('missing values in training data set :', train.isnull().sum())
# Out:
# missing values in training data set : S_2      0
# P_2      0
# D_39     0
# B_1      0
# B_2      0
#         ..
# D_140    0
# D_141    0
# D_143    0
# D_144    0
# D_145    0
# Length: 178, dtype: int64

# %% [markdown]
# ### Deal with date time

# %%
#feature creation
train['S_2_dayofweek'] = train['S_2'].dt.weekday
train['S_2_dayofmonth'] = train['S_2'].dt.day
train = train.drop(columns=['S_2'])

# %% [markdown]
# ### PCA Feature Selection

# %%
train = train.merge(y, left_index=True, right_index=True, how='left')

# %%
train.head()
# Out:
#                            P_2  D_39       B_1       B_2       R_1       S_3  \
# customer_ID
# 13914591055249847850  0.934745     0  0.009382  1.007647  0.006104  0.135021
# 11750091188498716901  0.880519     6  0.034684  1.004028  0.006911  0.165509
# 7128959966677571777   0.880875     0  0.004284  0.812649  0.006450  0.229062
# 6537921148391624412   0.621776     0  0.012564  1.006183  0.007829  0.287766
# 2065103583825424365   0.871900     0  0.007679  0.815746  0.001247  0.229062
#
#                       D_41       B_3      D_43  D_44  ...  D_138  D_139  \
# customer_ID                                           ...
# 13914591055249847850   0.0  0.007174  0.163763     0  ...     -1      0
# 11750091188498716901   0.0  0.005068  0.060646     0  ...     -1      0
# 7128959966677571777    0.0  0.007196  0.163763     0  ...     -1      0
# 6537921148391624412    0.0  0.009937  0.046104     0  ...     -1      0
# 2065103583825424365    0.0  0.005528  0.044671     0  ...     -1      0
#
#                       D_140  D_141  D_143     D_144  D_145  S_2_dayofweek  \
# customer_ID
# 13914591055249847850      0    0.0      0  0.002970      0              1
# 11750091188498716901      0    0.0      0  0.003169      0              6
# 7128959966677571777       0    0.0      0  0.000834      0              0
# 6537921148391624412       0    0.0      0  0.005560      0              3
# 2065103583825424365       0    0.0      0  0.006944      0              4
#
#                       S_2_dayofmonth  target
# customer_ID
# 13914591055249847850              13       0
# 11750091188498716901              25       0
# 7128959966677571777               12       0
# 6537921148391624412               29       0
# 2065103583825424365               30       0
#
# [5 rows x 180 columns]

# %%
#Cumulative Explained Variance explained by the components
# number of Principal components:27
transformer = IncrementalPCA(n_components=27)
train_pca = transformer.fit_transform(train.iloc[:,:-1])

# %%
train_pca_df=pd.DataFrame(train_pca)

# %% [markdown]
# # Machine Learning Models

# %% [markdown]
# ### Split Data

# %%
train_pca_df.head()
# Out:
#             0           1          2         3         4          5   \
# 0   652.873216  307.498018 -12.418427  1.017803 -0.810467  -7.448045
# 1   303.724847  -32.221681 -20.177674  4.396501 -0.274523  -5.930358
# 2 -1012.458015  -13.772412 -28.045417  5.482018  0.023204  -5.895226
# 3  -397.415252  285.560808 -20.122561  2.977111 -0.427864  -9.093937
# 4 -1012.523641  -13.803814 -20.470712  3.132295 -0.041359  10.968365
#
#          6         7          8          9   ...        17        18  \
# 0 -4.135032  0.733977 -14.169576  -3.136355  ...  0.012161 -0.374496
# 1  2.778015 -0.141011  -8.607245   8.389138  ... -0.005056  0.055270
# 2 -2.298894  0.394680 -10.073151  -5.557609  ... -0.025895  0.082064
# 3 -1.423652  0.382674   5.067887  12.497593  ... -0.060106 -0.217144
# 4 -8.850462  0.201472   1.054519  12.628264  ... -0.117518 -0.270248
#
#          19        20        21        22        23        24        25  \
# 0  1.264482  0.633252 -0.258036 -0.633671  0.206105 -2.049039 -0.049360
# 1 -1.623420 -1.229234 -1.521698 -1.031182  0.270474  2.983509 -2.316054
# 2 -2.227237 -1.677394 -1.737196 -1.848980  0.265594 -3.166713 -0.518928
# 3  1.024727  0.904255  0.907871  2.365351 -0.064884  0.415232  2.133228
# 4  2.159601  1.206614  0.027384 -0.216611 -0.077358  1.248184 -0.256863
#
#          26
# 0 -1.205019
# 1 -0.205647
# 2 -0.697512
# 3 -0.756710
# 4 -0.192523
#
# [5 rows x 27 columns]

# %%
# 30% for testing, 70% for training
x_train, x_test, y_train, y_test = train_test_split(train_pca_df, train['target'], test_size=0.3, random_state=0, stratify=y)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((321239, 27), (137674, 27), (321239,), (137674,))

# %% [markdown]
# ### Lightgbm

# %%
param_lgbm = {
            'metric': "binary_logloss",
            'boosting_type': "dart",
            'n_estimators':1000,
            'verbosity': -1,
            'lambda_l1': 3.1412416493672213e-06,
             'lambda_l2': 1.919550703890871,
             'num_leaves': 53,
             'feature_fraction': 0.8361911823947347,
             'bagging_fraction': 0.5246353885003125,
             'bagging_freq': 7,
             'min_child_samples': 91}

lgbm =LGBMClassifier(**param_lgbm).fit(x_train, y_train)

# %%
#prediction
prdeictions_lgbm = lgbm.predict_proba(x_test)
preds_lgbm = pd.DataFrame(prdeictions_lgbm)
pred_final_lgbm = np.array(preds_lgbm[1])
pred_final_lgbm
# Out:
# array([0.00149071, 0.00315772, 0.00201955, ..., 0.01090927, 0.04437709,
#        0.78643622])

# %% [markdown]
# ### xgbm

# %%
xgb_parms ={
    'booster': 'dart',
     'n_jobs':4,
     'n_estimators':500,
    'lambda': 4.091409953463271e-08,
    'alpha': 3.6353429991712695e-08,
    'subsample': 0.6423675532438815,
    'colsample_bytree': 0.7830450413657872,
    'max_depth': 9,
    'min_child_weight': 5,
    'eta': 0.3749337530972536,
    'gamma': 0.0745370910451703,
    'grow_policy': 'depthwise',
    'sample_type': 'uniform',
    'normalize_type': 'tree',
    'rate_drop': 0.0723975209176045,
    'skip_drop': 0.9026367296518939}

xgbm = XGBClassifier(**xgb_parms)
xgbm.fit(x_train, y_train)
# Out:
# [13:26:07] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_eek2t0c4ro/croots/recipe/xgboost-split_1659548960591/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(alpha=3.6353429991712695e-08, base_score=0.5, booster='dart',
#               colsample_bylevel=1, colsample_bynode=1,
#               colsample_bytree=0.7830450413657872, enable_categorical=False,
#               eta=0.3749337530972536, gamma=0.0745370910451703, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', lambda=4.091409953463271e-08,
#               learning_rate=0.374933749, max_delta_step=0, max_depth=9,
#               min_child_weight=5, missing=nan, monotone_constraints='()',
#               n_estimators=500, n_jobs=4, normalize_type='tree',
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               rate_drop=0.0723975209176045, reg_alpha=3.63534305e-08,
#               reg_lambda=4.09141023e-08, sample_type='uniform', ...)

# %%
#prediction
prdeictions_xgbm = xgbm.predict_proba(x_test)
preds_xgbm = pd.DataFrame(prdeictions_xgbm)
pred_final_xgbm = np.array(preds_xgbm[1])
pred_final_xgbm
# Out:
# array([2.5311316e-04, 6.3488398e-05, 4.3588417e-04, ..., 9.6202539e-03,
#        2.6996108e-03, 8.5414588e-01], dtype=float32)

# %% [markdown]
# ### Catboost

# %%
Params_cat={ 
    'objective': 'CrossEntropy',
    'n_estimators':1000,
    'colsample_bylevel': 0.07868805912943484,
    'depth': 9,
    'boosting_type': 'Plain',
    'bootstrap_type': 'MVS',
    }

cbm =CatBoostClassifier(**Params_cat).fit(x_train, y_train)
# Out:
# 0:	learn: 0.6819678	total: 77.2ms	remaining: 1m 17s
# 1:	learn: 0.6749746	total: 86.1ms	remaining: 42.9s
# 2:	learn: 0.6555902	total: 110ms	remaining: 36.6s
# 3:	learn: 0.6307222	total: 133ms	remaining: 33.2s
# 4:	learn: 0.6083639	total: 156ms	remaining: 31.1s
# 5:	learn: 0.6011658	total: 167ms	remaining: 27.6s
# 6:	learn: 0.5900201	total: 179ms	remaining: 25.4s
# 7:	learn: 0.5740742	total: 200ms	remaining: 24.8s
# 8:	learn: 0.5569249	total: 223ms	remaining: 24.6s
# 9:	learn: 0.5400625	total: 248ms	remaining: 24.5s
# 10:	learn: 0.5304341	total: 262ms	remaining: 23.6s
# 11:	learn: 0.5251195	total: 275ms	remaining: 22.6s
# 12:	learn: 0.5120639	total: 300ms	remaining: 22.8s
# 13:	learn: 0.5097468	total: 312ms	remaining: 21.9s
# 14:	learn: 0.4960095	total: 335ms	remaining: 22s
# 15:	learn: 0.4893641	total: 353ms	remaining: 21.7s
# 16:	learn: 0.4875672	total: 363ms	remaining: 21s
# 17:	learn: 0.4809951	total: 376ms	remaining: 20.5s
# 18:	learn: 0.4733542	total: 393ms	remaining: 20.3s
# 19:	learn: 0.4635915	total: 415ms	remaining: 20.3s
# 20:	learn: 0.4623310	total: 425ms	remaining: 19.8s
# 21:	learn: 0.4533733	total: 447ms	remaining: 19.9s
# 22:	learn: 0.4424044	total: 472ms	remaining: 20s
# 23:	learn: 0.4346034	total: 495ms	remaining: 20.1s
# 24:	learn: 0.4308971	total: 516ms	remaining: 20.1s
# 583:	learn: 0.2717803	total: 9.85s	remaining: 7.02s
# 584:	learn: 0.2717790	total: 9.86s	remaining: 7s
# 585:	learn: 0.2717209	total: 9.88s	remaining: 6.98s
# 586:	learn: 0.2716519	total: 9.91s	remaining: 6.97s
# 587:	learn: 0.2716245	total: 9.93s	remaining: 6.95s
# 588:	learn: 0.2716061	total: 9.94s	remaining: 6.94s
# 589:	learn: 0.2715591	total: 9.96s	remaining: 6.92s
# 590:	learn: 0.2715272	total: 9.99s	remaining: 6.91s
# 591:	learn: 0.2715002	total: 10s	remaining: 6.89s
# 592:	learn: 0.2714948	total: 10s	remaining: 6.87s
# 593:	learn: 0.2714863	total: 10s	remaining: 6.86s
# 594:	learn: 0.2714769	total: 10s	remaining: 6.84s
# 595:	learn: 0.2714499	total: 10.1s	remaining: 6.82s
# 596:	learn: 0.2714489	total: 10.1s	remaining: 6.8s
# 597:	learn: 0.2714431	total: 10.1s	remaining: 6.78s
# 598:	learn: 0.2714326	total: 10.1s	remaining: 6.76s
# 599:	learn: 0.2713956	total: 10.1s	remaining: 6.75s
# 600:	learn: 0.2713956	total: 10.1s	remaining: 6.72s
# 601:	learn: 0.2713266	total: 10.2s	remaining: 6.71s
# 602:	learn: 0.2713169	total: 10.2s	remaining: 6.69s
# 603:	learn: 0.2712712	total: 10.2s	remaining: 6.68s
# 604:	learn: 0.2712652	total: 10.2s	remaining: 6.66s
# 605:	learn: 0.2711982	total: 10.2s	remaining: 6.64s
# 606:	learn: 0.2711982	total: 10.2s	remaining: 6.62s
# 607:	learn: 0.2711433	total: 10.3s	remaining: 6.61s
# 608:	learn: 0.2711081	total: 10.3s	remaining: 6.59s
# 609:	learn: 0.2711019	total: 10.3s	remaining: 6.57s
# 610:	learn: 0.2710733	total: 10.3s	remaining: 6.55s
# 611:	learn: 0.2710199	total: 10.3s	remaining: 6.54s
# 612:	learn: 0.2709746	total: 10.3s	remaining: 6.53s
# 613:	learn: 0.2709746	total: 10.4s	remaining: 6.51s
# 614:	learn: 0.2709728	total: 10.4s	remaining: 6.49s
# 615:	learn: 0.2708973	total: 10.4s	remaining: 6.47s
# 616:	learn: 0.2708886	total: 10.4s	remaining: 6.46s
# 617:	learn: 0.2708671	total: 10.4s	remaining: 6.44s
# 618:	learn: 0.2708461	total: 10.4s	remaining: 6.42s
# 619:	learn: 0.2708461	total: 10.4s	remaining: 6.4s
# 620:	learn: 0.2707950	total: 10.5s	remaining: 6.39s
# 621:	learn: 0.2707889	total: 10.5s	remaining: 6.37s
# 622:	learn: 0.2707889	total: 10.5s	remaining: 6.35s
# 623:	learn: 0.2707378	total: 10.5s	remaining: 6.34s
# 624:	learn: 0.2707310	total: 10.5s	remaining: 6.32s
# 625:	learn: 0.2706508	total: 10.6s	remaining: 6.3s
# 626:	learn: 0.2706364	total: 10.6s	remaining: 6.29s
# 627:	learn: 0.2705799	total: 10.6s	remaining: 6.28s
# 628:	learn: 0.2705040	total: 10.6s	remaining: 6.26s
# 629:	learn: 0.2704886	total: 10.6s	remaining: 6.25s
# 630:	learn: 0.2704755	total: 10.7s	remaining: 6.23s
# 631:	learn: 0.2704716	total: 10.7s	remaining: 6.21s
# 632:	learn: 0.2703907	total: 10.7s	remaining: 6.2s
# 633:	learn: 0.2703186	total: 10.7s	remaining: 6.18s
# 634:	learn: 0.2703186	total: 10.7s	remaining: 6.16s
# 635:	learn: 0.2702712	total: 10.7s	remaining: 6.15s
# 636:	learn: 0.2702567	total: 10.8s	remaining: 6.13s
# 637:	learn: 0.2702108	total: 10.8s	remaining: 6.12s
# 638:	learn: 0.2702108	total: 10.8s	remaining: 6.1s
# 639:	learn: 0.2701581	total: 10.8s	remaining: 6.08s
# 640:	learn: 0.2701570	total: 10.8s	remaining: 6.06s
# 641:	learn: 0.2700837	total: 10.8s	remaining: 6.05s
# 642:	learn: 0.2700019	total: 10.9s	remaining: 6.04s
# 643:	learn: 0.2699919	total: 10.9s	remaining: 6.02s
# 644:	learn: 0.2699908	total: 10.9s	remaining: 6s
# 645:	learn: 0.2699908	total: 10.9s	remaining: 5.98s
# 646:	learn: 0.2699871	total: 10.9s	remaining: 5.96s
# 647:	learn: 0.2699294	total: 10.9s	remaining: 5.94s
# 648:	learn: 0.2698598	total: 11s	remaining: 5.93s
# 649:	learn: 0.2698598	total: 11s	remaining: 5.91s
# 650:	learn: 0.2698598	total: 11s	remaining: 5.89s
# 651:	learn: 0.2698437	total: 11s	remaining: 5.87s
# 652:	learn: 0.2697861	total: 11s	remaining: 5.86s
# 653:	learn: 0.2697826	total: 11s	remaining: 5.84s
# 654:	learn: 0.2697605	total: 11.1s	remaining: 5.82s
# 655:	learn: 0.2697588	total: 11.1s	remaining: 5.8s
# 656:	learn: 0.2697401	total: 11.1s	remaining: 5.78s
# 657:	learn: 0.2697212	total: 11.1s	remaining: 5.76s
# 658:	learn: 0.2696705	total: 11.1s	remaining: 5.75s
# 659:	learn: 0.2696322	total: 11.1s	remaining: 5.74s
# 660:	learn: 0.2696315	total: 11.1s	remaining: 5.72s
# 661:	learn: 0.2696266	total: 11.2s	remaining: 5.7s
# 662:	learn: 0.2695735	total: 11.2s	remaining: 5.68s
# 663:	learn: 0.2695518	total: 11.2s	remaining: 5.67s
# 664:	learn: 0.2695486	total: 11.2s	remaining: 5.65s
# 665:	learn: 0.2695486	total: 11.2s	remaining: 5.63s
# 666:	learn: 0.2694795	total: 11.2s	remaining: 5.61s
# 667:	learn: 0.2694026	total: 11.3s	remaining: 5.6s
# 668:	learn: 0.2693616	total: 11.3s	remaining: 5.58s
# 669:	learn: 0.2693504	total: 11.3s	remaining: 5.56s
# 670:	learn: 0.2693467	total: 11.3s	remaining: 5.54s
# 671:	learn: 0.2693448	total: 11.3s	remaining: 5.52s
# 672:	learn: 0.2692792	total: 11.3s	remaining: 5.51s
# 673:	learn: 0.2692195	total: 11.4s	remaining: 5.5s
# 674:	learn: 0.2691583	total: 11.4s	remaining: 5.48s
# 675:	learn: 0.2690974	total: 11.4s	remaining: 5.47s
# 862:	learn: 0.2646738	total: 14.6s	remaining: 2.31s
# 863:	learn: 0.2646206	total: 14.6s	remaining: 2.29s
# 864:	learn: 0.2646121	total: 14.6s	remaining: 2.28s
# 865:	learn: 0.2646112	total: 14.6s	remaining: 2.26s
# 866:	learn: 0.2646082	total: 14.6s	remaining: 2.24s
# 867:	learn: 0.2646037	total: 14.6s	remaining: 2.22s
# 868:	learn: 0.2646037	total: 14.6s	remaining: 2.21s
# 869:	learn: 0.2645986	total: 14.6s	remaining: 2.19s
# 870:	learn: 0.2645978	total: 14.7s	remaining: 2.17s
# 871:	learn: 0.2645564	total: 14.7s	remaining: 2.15s
# 872:	learn: 0.2645521	total: 14.7s	remaining: 2.14s
# 873:	learn: 0.2645492	total: 14.7s	remaining: 2.12s
# 874:	learn: 0.2645357	total: 14.7s	remaining: 2.1s
# 875:	learn: 0.2645005	total: 14.7s	remaining: 2.08s
# 876:	learn: 0.2644935	total: 14.7s	remaining: 2.07s
# 877:	learn: 0.2644481	total: 14.8s	remaining: 2.05s
# 878:	learn: 0.2644368	total: 14.8s	remaining: 2.04s
# 879:	learn: 0.2643898	total: 14.8s	remaining: 2.02s
# 880:	learn: 0.2643898	total: 14.8s	remaining: 2s
# 881:	learn: 0.2643465	total: 14.8s	remaining: 1.99s
# 882:	learn: 0.2642964	total: 14.9s	remaining: 1.97s
# 883:	learn: 0.2642937	total: 14.9s	remaining: 1.95s
# 884:	learn: 0.2642508	total: 14.9s	remaining: 1.94s
# 885:	learn: 0.2642062	total: 14.9s	remaining: 1.92s
# 886:	learn: 0.2642062	total: 14.9s	remaining: 1.9s
# 887:	learn: 0.2642045	total: 14.9s	remaining: 1.89s
# 888:	learn: 0.2641790	total: 15s	remaining: 1.87s
# 889:	learn: 0.2641468	total: 15s	remaining: 1.85s
# 890:	learn: 0.2641468	total: 15s	remaining: 1.83s
# 891:	learn: 0.2641388	total: 15s	remaining: 1.82s
# 892:	learn: 0.2641190	total: 15s	remaining: 1.8s
# 893:	learn: 0.2640652	total: 15s	remaining: 1.78s
# 894:	learn: 0.2640631	total: 15.1s	remaining: 1.77s
# 895:	learn: 0.2640285	total: 15.1s	remaining: 1.75s
# 896:	learn: 0.2639817	total: 15.1s	remaining: 1.73s
# 897:	learn: 0.2639684	total: 15.1s	remaining: 1.72s
# 898:	learn: 0.2639223	total: 15.2s	remaining: 1.7s
# 899:	learn: 0.2639127	total: 15.2s	remaining: 1.69s
# 900:	learn: 0.2639095	total: 15.2s	remaining: 1.67s
# 901:	learn: 0.2638412	total: 15.2s	remaining: 1.65s
# 902:	learn: 0.2638379	total: 15.2s	remaining: 1.63s
# 903:	learn: 0.2638342	total: 15.2s	remaining: 1.62s
# 904:	learn: 0.2637891	total: 15.2s	remaining: 1.6s
# 905:	learn: 0.2637458	total: 15.3s	remaining: 1.58s
# 906:	learn: 0.2637108	total: 15.3s	remaining: 1.57s
# 907:	learn: 0.2636692	total: 15.3s	remaining: 1.55s
# 908:	learn: 0.2636244	total: 15.3s	remaining: 1.53s
# 909:	learn: 0.2636244	total: 15.3s	remaining: 1.52s
# 910:	learn: 0.2635899	total: 15.4s	remaining: 1.5s
# 911:	learn: 0.2635751	total: 15.4s	remaining: 1.48s
# 912:	learn: 0.2635550	total: 15.4s	remaining: 1.47s
# 913:	learn: 0.2635499	total: 15.4s	remaining: 1.45s
# 914:	learn: 0.2635499	total: 15.4s	remaining: 1.43s
# 915:	learn: 0.2635499	total: 15.4s	remaining: 1.42s
# 916:	learn: 0.2635063	total: 15.5s	remaining: 1.4s
# 917:	learn: 0.2634630	total: 15.5s	remaining: 1.38s
# 918:	learn: 0.2634176	total: 15.5s	remaining: 1.37s
# 919:	learn: 0.2634053	total: 15.5s	remaining: 1.35s
# 920:	learn: 0.2633551	total: 15.6s	remaining: 1.33s
# 921:	learn: 0.2633543	total: 15.6s	remaining: 1.32s
# 922:	learn: 0.2633528	total: 15.6s	remaining: 1.3s
# 923:	learn: 0.2633491	total: 15.6s	remaining: 1.28s
# 924:	learn: 0.2633435	total: 15.6s	remaining: 1.26s
# 925:	learn: 0.2633058	total: 15.6s	remaining: 1.25s
# 926:	learn: 0.2633058	total: 15.6s	remaining: 1.23s
# 927:	learn: 0.2632955	total: 15.6s	remaining: 1.21s
# 928:	learn: 0.2632581	total: 15.7s	remaining: 1.2s
# 929:	learn: 0.2632416	total: 15.7s	remaining: 1.18s
# 930:	learn: 0.2632114	total: 15.7s	remaining: 1.16s
# 931:	learn: 0.2632095	total: 15.7s	remaining: 1.15s
# 932:	learn: 0.2631786	total: 15.7s	remaining: 1.13s
# 933:	learn: 0.2631245	total: 15.8s	remaining: 1.11s
# 934:	learn: 0.2630883	total: 15.8s	remaining: 1.1s
# 935:	learn: 0.2630347	total: 15.8s	remaining: 1.08s
# 936:	learn: 0.2630318	total: 15.8s	remaining: 1.06s
# 937:	learn: 0.2630285	total: 15.8s	remaining: 1.05s
# 938:	learn: 0.2629809	total: 15.8s	remaining: 1.03s
# 939:	learn: 0.2629780	total: 15.9s	remaining: 1.01s
# 940:	learn: 0.2629754	total: 15.9s	remaining: 995ms
# 941:	learn: 0.2629746	total: 15.9s	remaining: 978ms
# 942:	learn: 0.2629620	total: 15.9s	remaining: 961ms
# 943:	learn: 0.2629562	total: 15.9s	remaining: 944ms
# 944:	learn: 0.2629518	total: 15.9s	remaining: 927ms
# 945:	learn: 0.2629518	total: 15.9s	remaining: 910ms
# 946:	learn: 0.2629512	total: 15.9s	remaining: 892ms
# 947:	learn: 0.2629447	total: 16s	remaining: 875ms
# 948:	learn: 0.2629424	total: 16s	remaining: 858ms
# 949:	learn: 0.2628947	total: 16s	remaining: 842ms
# 950:	learn: 0.2628665	total: 16s	remaining: 825ms
# 951:	learn: 0.2628640	total: 16s	remaining: 808ms
# 952:	learn: 0.2628497	total: 16s	remaining: 791ms
# 953:	learn: 0.2628467	total: 16.1s	remaining: 774ms
# 954:	learn: 0.2628448	total: 16.1s	remaining: 757ms
# 955:	learn: 0.2628279	total: 16.1s	remaining: 740ms
# array([0.00306359, 0.00590065, 0.00402013, ..., 0.01308868, 0.03674958,
#        0.80463141])

# %% [markdown]
# ### Random Forest

# %%
#random forest classifier
forest = RandomForestClassifier(criterion='entropy',random_state=50,n_estimators=100,)
forest.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', random_state=50)

# %%
#prediction
predict_y_rf = forest.predict_proba(x_test)
preds_rf = pd.DataFrame(predict_y_rf)
pred_final_rf = np.array(preds_rf[1])
pred_final_rf
# Out:
# array([0.  , 0.01, 0.  , ..., 0.01, 0.03, 0.77])

# %% [markdown]
# ### Logistic Regression

# %%
logreg = LogisticRegression()
LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
                   intercept_scaling=1, l1_ratio=None, max_iter=100,
                   multi_class='warn', n_jobs=None, penalty='l2',
                   random_state=None, solver='warn', tol=0.0001, verbose=0,
                   warm_start=False)
logreg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#prediction
predict_y_logistic=logreg.predict_proba(x_test)
preds_logistic = pd.DataFrame(predict_y_logistic)
pred_final_logistic = np.array(preds_logistic[1])
pred_final_logistic
# Out:
# array([0.0536075 , 0.10505094, 0.10627271, ..., 0.13032637, 0.29519976,
#        0.78970713])

# %% [markdown]
# ### Evluation

# %%
y_true=y_test.reset_index()
y_true
#pred_final_lgbm,pred_final_xgbm,pred_final_cbm,pred_final_rf,pred_final_logistic
# Out:
#                  customer_ID  target
# 0        1438258030537934421       0
# 1        7862704852926137339       0
# 2       14820336679247132372       0
# 3       16399199556160497916       1
# 4       13982988533756619543       0
# ...                      ...     ...
# 137669  13311305499010140177       0
# 137670  17811584250307115404       0
# 137671  15119483344209594545       0
# 137672   5084016308273490973       0
# 137673  16371442952285775785       1
#
# [137674 rows x 2 columns]

# %%
#pred_final_lgbm,pred_final_xgbm,pred_final_cbm,pred_final_rf,pred_final_logistic
pred_lgbm_df=pd.DataFrame(pred_final_lgbm)
pred_lgbm_df=pd.DataFrame(pred_final_lgbm)
pred_lgbm_df=pd.DataFrame(pred_final_lgbm)
pred_lgbm_df=pd.DataFrame(pred_final_lgbm)
# Out:
#           0
# 0  0.001491
# 1  0.003158
# 2  0.002020
# 3  0.130000
# 4  0.121660

# %%
pred_lgbm_df=pd.DataFrame(pred_final_lgbm)
pred_xgbm_df=pd.DataFrame(pred_final_xgbm)
pred_cbm_df=pd.DataFrame(pred_final_cbm)
pred_rf_df=pd.DataFrame(pred_final_rf)
pred_logistic_df=pd.DataFrame(pred_final_logistic)
pred_lgbm_df.columns=['prediction']
pred_xgbm_df.columns=['prediction']
pred_cbm_df.columns=['prediction']
pred_rf_df.columns=['prediction']
pred_logistic_df.columns=['prediction']

# %%
print('lgbm:',amex_metric(y_true,pred_lgbm_df))
print('xgbm:',amex_metric(y_true,pred_xgbm_df))
print('cbm:',amex_metric(y_true,pred_cbm_df))
print('rf:',amex_metric(y_true,pred_rf_df))
print('logistic:',amex_metric(y_true,pred_logistic_df))
# Out:
# lgbm: 0.7192125156065636
# xgbm: 0.6711487964956283
# cbm: 0.7085156413873195
# rf: 0.6959572093431239
# logistic: 0.6426848643280002
